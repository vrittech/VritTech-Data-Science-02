# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# * Mean Absolute Error (MAE): $\frac{\sum_{i=1}^{N}|y_{actual} - y_{predicted}|}{N}$
# * Mean Squared Error (MSE): $\frac{\sum_{i=1}^{N}(y_{actual} - y_{predicted})^2}{N}$
# * R2: $1 - \frac{\sum(y_{actual} - y_{predicted})^2}{\sum(y_{actual} - y_{mean})^2}$

# %%
X = np.random.normal(10, 2, 120)
y = X + np.random.normal(3, 0.5, 120)

# %%
X[:5]
# Out:
# array([10.97713136,  8.40943797,  9.11674506,  8.71633928,  8.01036186])

# %%
y[:5]
# Out:
# array([14.50699919, 11.2435682 , 12.31658374, 11.37034366,  9.77082194])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    shuffle=True,
                                                    random_state=666)

# %%
plt.scatter(X_train, y_train, c='b', label='Training Data')
plt.scatter(X_test, y_test, c='r', label='Testing Data')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
m, c, r2, _, err= linregress(X_train, y_train)

# %%
m
# Out:
# 1.0075547067293364

# %%
c
# Out:
# 2.9110221262730036

# %%
r2
# Out:
# 0.9716038080816595

# %%
reg_line_train = m * X_train + c

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, reg_line_train, c='r')
plt.show()

# %%
reg_line_test = m * X_test + c

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, reg_line_test, c='r')
plt.show()

# %%
def predict(x_new):
    return m * x_new + c

# %%
predict(14)
# Out:
# 17.016788020483716

# %%
predict(0)
# Out:
# 2.9110221262730036

# %%
predict(-5)
# Out:
# -2.1267514073736784

# %%
lin_reg = LinearRegression(n_jobs=-1)

# %%
X_train[:5]
# Out:
# array([12.74822634, 10.82864187, 11.02702978, 11.8283316 ,  8.86326285])

# %%
[1, 2, 3, 4, 5]
[[1], [2], [3], [4], ]
lin_reg.fit(X_train.reshape(-1, 1), y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
lin_reg.intercept_
# Out:
# 2.9110221262729965

# %%
c
# Out:
# 2.9110221262730036

# %%
lin_reg.coef_
# Out:
# array([1.00755471])

# %%
m
# Out:
# 1.0075547067293364

# %%
lin_reg.predict([[1], [5], [8]])
# Out:
# array([ 3.91857683,  7.94879566, 10.97145978])

# %%
y_pred = lin_reg.predict(X_test.reshape(-1, 1))

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.40853087657562764

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9248309332585912

# %%
45 - 0.4085
